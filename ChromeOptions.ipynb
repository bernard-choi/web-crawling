# %%
from selenium import webdriver
opt2 = webdriver.ChromeOptions()
# opt.add_argument('headless')
# opt2.add_argument('--window-size=1920,1080')
browser = webdriver.Chrome("C://Users/User//Desktop/chromedriver.exe", chrome_options=opt2)
browser.set_window_size(1920,1080)
##다른 크롬?
## Extension adblock 광고 안보이게하는거? 크롬에 깔려있다? 어도비플레이어?
## 크롬 설정에 많은게 있는데....
## 크롬드라이버에서도 활성화할 수 있게...

## 웹에 대한 공부가 필요할꺼같다. 
## CLI GUI???
## headless 팬텀 js
## phantom js 안되면 해결 안된다?
## 크롬으로 사용한다? 무슨말이지?
## headless모드 렌더링
## html 문서.... 서버에서 받아오면 뭐가 뭔지 모른다. borwser 
##창이 가상으로 떠 있는 상태

# %%
##방법2
# browser.set_window_size(1920,1080)

# %%
url = "https://www.naver.com"
browser.get(url)

# %%
from bs4 import BeautifulSoup
html  = browser.page_source
soup = BeautifulSoup(html,"lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="svgless" lang="ko" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title"/>
# <meta content="index,nofollow" name="robots"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# ...

# %%
## Rendering 을 줄여서 시간을 단축하는 코드이다.

# %%
## Window - size
## 어중간한 크기의 창
## 기본적인 디폴트값 변경 가능
## 최대한 꽉차게 - 1

# %%
## 창크기 끝나고 다음은?
##  MultiProcessing url 100개가 있으면 크롤링 그냥시키면 1~100까지 차근차근한다.

# %%
from bs4 import BeautifulSoup
import requests
import re
from multiprocessing import Pool, Process
import time

# %%
def get_stars(pnum):
    base_url = 'http://deal.11st.co.kr/product/SellerProductDetail.tmall?method=getProductReviewList&prdNo=87595509&page={0}&pageTypCd=first&reviewDispYn=Y&isPreview=false&reviewOptDispYn=n&optSearchBtnAndGraphLayer=n&reviewBottomBtn=Y&openDetailContents=Y&pageSize=10&isIgnoreAuth=false&lctgrNo=1001369&leafCtgrNo=0&groupProductNo=0&groupFirstViewPrdNo=0&selNo=16674487#this'
    stars_int = []
    url = base_url.format(pnum+1)
    response = requests.get(url)
    html = response.text
    soup1 = BeautifulSoup(html,"lxml")
    reviews = soup1.find_all(id = "reviewContTxt")
    p = re.compile('^selr_star selr_star')
    stars = [int(x.text[-2]) for x in soup1.find_all('span', class_ = p)]
    stars_int.extend(stars)
    print('{0}page까지 완료'.format(pnum+1))
    return stars_int

# %%
st = time.time()
for i in range(0,100):
    get_stars(i)
t_spend = time.time()-st
print('그냥 실행 : ',t_spend)
# Out:
# 1page까지 완료
# 2page까지 완료
# 3page까지 완료
# 4page까지 완료
# 5page까지 완료
# 6page까지 완료
# 7page까지 완료
# 8page까지 완료
# 9page까지 완료
# 10page까지 완료
# 11page까지 완료
# 12page까지 완료
# 13page까지 완료
# 14page까지 완료
# 15page까지 완료
# 16page까지 완료
# 17page까지 완료
# 18page까지 완료
# 19page까지 완료
# 20page까지 완료
# 21page까지 완료
# 22page까지 완료
# 23page까지 완료
# 24page까지 완료
# 25page까지 완료
# 26page까지 완료
# 27page까지 완료
# 28page까지 완료
# 29page까지 완료
# 30page까지 완료
# 31page까지 완료
# 32page까지 완료
# 33page까지 완료
# 34page까지 완료
# 35page까지 완료
# 36page까지 완료
# 37page까지 완료
# 38page까지 완료
# 39page까지 완료
# 40page까지 완료
# 41page까지 완료
# 42page까지 완료
# 43page까지 완료
# 44page까지 완료
# 45page까지 완료
# 46page까지 완료
# 47page까지 완료
# 48page까지 완료
# 49page까지 완료
# 50page까지 완료
# 51page까지 완료
# 52page까지 완료
# 53page까지 완료
# 54page까지 완료
# 55page까지 완료
# 56page까지 완료
# 57page까지 완료
# 58page까지 완료
# 59page까지 완료
# 60page까지 완료
# 61page까지 완료
# 62page까지 완료
# 63page까지 완료
# 64page까지 완료
# 65page까지 완료
# 66page까지 완료
# 67page까지 완료
# 68page까지 완료
# 69page까지 완료
# 70page까지 완료
# 71page까지 완료
# 72page까지 완료
# ...

# %%
st_mul = time.time()
p = Pool(processes=4)
p.apply(get_stars,list(range(1,101)))
t_spend_mul = time.time()-st_mul
print('멀티 프로세싱 시 : ',t_spend_mul) ## 이것이 작동이 되지 않는다... 왤까

# %%
import math

print(sum(stars_int)/len(stars_int))
